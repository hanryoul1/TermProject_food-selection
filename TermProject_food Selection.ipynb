# %%
answer = int(input("Welcome to Today's menu selection! Would you like to choose a menu? If you want please enter '0', if you don't want enter '1': "))

while answer != 0:
    
    if answer == 1:
        print("Then exit the program.")
        break
        
    else:
        print("Enter the correct answers.")
        answer = int(input("If you want, please enter '0', don't want enter '1': "))
    
if answer == 0:
    print("Let's start choosing the menu!")
    print("First, you have to select a cultural area. You have two choices, The East and The West.")
    cultural = int(input("The East is '0', The West is '1'. Please enter the number which you want correctly.: "))
    
    while cultural != 0:
        
        if cultural == 1:
            print("Second, you have to select a country. You have three choices, Italy, France and The USA.")
            wcountry = int(input("Italy is '0', France is '1', The USA is '2'. Please enter the number which you want correctly.: " ))
            
            if wcountry == 0:
                print("Third, you have to select a food type. You have two choices, Noodle and Not noodle.")
                itype = int(input("Noodle is '0' and Not noodle is '1'. Please enter the number which you want correctly.: "))
                
                while itype !=0:
                    
                    if itype == 1:
                        print("I recommend risotto, frittata, and napoli pizza.")
                        break
                        
                    else:
                        itype = int(input("Noodle is '0' and Not noodle is '1'. Please enter the number which you want correctly.: "))
                        
                if itype == 0:
                    print("I recommend Pasta and lasagna.")
                    
                break
        
            if wcountry == 1:
                print("Third, you have to select a food type. You have two choices, Dessert and Meal.")
                ftype = int(input("Dessert is '0' and Meal is '1'. Please enter the number which you want correctly.: "))
            
                while ftype != 0:
            
                    if ftype == 1:
                        print("I recommend Onion soup, Coq au vin and bouillabaisse.")
                        break
                    
                    else:
                        ftype = int(input("Dessert is '0' and Meal is '1'. Please enter the number which you want correctly.: "))
                    
                if ftype == 0:
                    print("I recommend Macaron, tart and madeleine.")
                    
                break
            
            if wcountry == 2:
                print("Third, you have to select a food type. You have two choices, Meat and Not meat.")
                utype = int(input("Meat is '0' Not meat is '1'. Please enter the number which you want correctly.: "))
                
                while utype != 0:
            
                    if utype == 1:
                        print("I recommend Mac n Cheese and Egg Benedict.")
                        break
                    
                    else: 
                        utype = int(input("Meat is '0' Not meat is '1'. Please enter the number which you want correctly.: "))
                        
                if utype == 0:
                    print("I recommend Fried chicken, hamburgers and hot dogs.")
                    
                break
            
                
        else:
            print("Enter the correct answers.")
            cultural = int(input("The East is '0', The West is '1'. Please enter the number which you want correctly.: "))
        
    if cultural == 0:
        print("Second, you have to select a country. You have four choices, Japan, China, Korea and Southest Aisia.")
        ecountry = int(input("Japan is '0', China is '1', Korea is '2', Southest Aisia is '3'. Please enter the number which you want correctly.: " ))
        
        while ecountry != 0:
        
            if ecountry == 1:
                print("Third, you have to select a food type. You have two choices, Sichuan and Guangdong regions.")
                ctype = int(input("Sichuan is '0' and Guangdong is '1'. Please enter the number which you want correctly.: "))
                
                while ctype != 0:
            
                    if ctype == 1:
                        print("I recommend Sweet and sour pork, dim sum, shrimp gyoza, and wantangmyeon.")
                        break
                        
                    else:
                        ctype = int(input("Sichuan is '0' and Guangdong is '1'. Please enter the number which you want correctly.: "))
                        
                if ctype == 0:
                    print("I recommend hwogwo, Mapa tofu, Malatang and Malaxianguo.")
                    
                break
        
            if ecountry == 2:
                print("Third, you have to select a food type. You have two choices, Rice and Not rice.")
                ktype = int(input("Rice is '0' and Not rice is '1'. Please enter the number which you want correctly.: "))
                
                while ktype != 0:
            
                    if ktype == 1:
                        print("I recommend Tteokbokki, and seafood pancake.")
                        break
                        
                    else:
                        ktype = int(input("Rice is '0' and Not rice is '1'. Please enter the number which you want correctly.: "))
                        
                if ktype == 0:
                     print("I recommend bibimbap, kimbap, yukgaejang and sundaegug.")
                        
                break
        
            if ecountry == 3:
                print("Third, you have to select a food type. You have two choices, Rice and Not rice.")
                stype = int(input("Rice is '0' and Not rice is '1'. Please enter the number which you want correctly.: "))
                
                while stype != 0:
            
                    if stype == 1:
                        print("I recommend banmi Sandwich, buncha and chajo.")
                        break
                    
                    else:
                        stype = int(input("Rice is '0' and Not rice is '1'. Please enter the number which you want correctly.: "))
                    
                if stype == 0:
                     print("I recommend Rice noodle, pineapple fried rice and nasi goreng.")
                        
                break
            
            else:
                ecountry = int(input("Japan is '0', China is '1', Korea is '2', Southest Aisia is '3'. Please enter the number which you want correctly.: " ))
            
        if ecountry == 0:
            print("Third, you have to select a food type. You have two choices, Noodle and Not noodle.")
            jtype = int(input("Noodle is '0' and Not noodle is '1'. Please enter the number which you want correctly.: "))
            
            while jtype != 0:
            
                if jtype == 1:
                    print("I recommend Okonomiyaki, Gyudon, Katsudon and Millefeuyunabe to you.")
                    break
                
                else:
                    jtype = int(input("Noodle is '0' and Not noodle is '1'. Please enter the number which you want correctly.: "))
                    
            if jtype == 0:
                print("I recommend udon and ramen to you.")
            
                
    lastanswer = int(input("Do you like the result? If you like please enter '0', if you don't enter '1': "))
    
    while lastanswer != 1:
    
        if lastanswer == 0:
            print("Have a good meal time. Exit the program.")
            break
        
        else:
            print("Enter the correct answers.")
            lastanswer = int(input("Do you like the result? If you like please enter '0', if you don't enter '1': "))

    if lastanswer == 1:
        tryagain = int(input("Do you want to try again? If you want please enter '0', if you don't want enter '1': "))
        
        while tryagain != 1:
            
            if tryagain == 0:
                print("First, you have to select a cultural area. You have two choices, The East and The West.")
                cultural = int(input("The East is '0', The West is '1'. Please enter the number which you want correctly.: "))
                break
                
            else:
                print("Enter the correct answers.")
                tryagain = int(input("Do you want to try again? If you want please enter '0', if you don't want enter '1': "))
                
        if tryagain ==1:
            print("Then exit the program.")
# Out:
# Welcome to Today's menu selection! Would you like to choose a menu? If you want please enter '0', if you don't want enter '1': 0
# Let's start choosing the menu!
# First, you have to select a cultural area. You have two choices, The East and The West.
# The East is '0', The West is '1'. Please enter the number which you want correctly.: 0
# Second, you have to select a country. You have four choices, Japan, China, Korea and Southest Aisia.
# Japan is '0', China is '1', Korea is '2', Southest Aisia is '3'. Please enter the number which you want correctly.: 5
# Japan is '0', China is '1', Korea is '2', Southest Aisia is '3'. Please enter the number which you want correctly.: 4
# Japan is '0', China is '1', Korea is '2', Southest Aisia is '3'. Please enter the number which you want correctly.: 3
# Third, you have to select a food type. You have two choices, Rice and Not rice.
# Rice is '0' and Not rice is '1'. Please enter the number which you want correctly.: 5
# ...
